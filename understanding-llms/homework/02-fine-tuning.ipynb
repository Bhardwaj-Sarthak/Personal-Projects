# %% [markdown]
# # Homework 2: Fine-tuning & Prompting of LMs (51 points)
#
# The focus of this homework is on one prominent fine-tuning technique -- reinforcement learning from human feedback -- and on critically thinking about prompting techniques and papers about language models
#
# ### Logistics
#
# * submission deadline: June 3rd th 23:59 German time via Moodle
#   * please upload a **SINGLE .IPYNB FILE named Surname_FirstName_HW2.ipynb** containing your solutions of the homework.
# * please solve and submit the homework **individually**!
# * if you use Colab, to speed up the execution of the code on Colab, you can use the available GPU (if Colab resources allow). For that, before executing your code, navigate to Runtime > Change runtime type > GPU > Save.

# %% [markdown]
# ## Exercise 1: Advanced prompting strategies (16 points)
#
# The lecture discussed various sophisticated ways of prompting language models for generating texts. Please answer the following questions about prompting techniques in context of different models, and write down your answers, briefly explaining them (max. 3 sentences). Feel free to actually try out some of the prompting strategies to play around with them and build your intuitions.
#
# > Consider the following language models:
# > * GPT-4, Qwen-2.5-Coder-32B, Mistral-24B-Instruct, Llama-2-70b-base.
# >
# > Consider the following prompting / generation strategies:
# > * tree-of-thought reasoning, zero-shot chain-of-thought prompting, few-shot prompting, self-reflection prompting.
# >
# > For each model:
# > * which strategies do you think work well, and why?
# >
# > For each prompting strategy:
# > * Name an example task or context, and model, in which you would think they work best. Briefly justify why.

# %% [markdown]
# ## Exercise 2: RLHF for summarization (15 points)
#
# In this exercise, we want to fine-tune GPT-2 to generate human-like news summaries, following a procedure that is very similar to the example of the movie review generation from [sheet 4.1](https://cogsciprag.github.io/Understanding-LLMs-course/tutorials/04a-finetuning-RL.html). The exercise is based on the paper by [Ziegler et al. (2020)](https://arxiv.org/pdf/1909.08593).
#
# To this end, we will use the following components:
# * in order to initialize the policy, we use GPT-2 that was already fine-tuned for summarization, i.e., our SFT model is [this](https://huggingface.co/gavin124/gpt2-finetuned-cnn-summarization-v2)
# * as our reward model, we will use a task-specific reward signal, namely, the ROUGE score that evaluates a summary generated by a model against a human "gold standard" summary.
# * a dataset of CNN news texts and human-written summaries (for computing the rewards) for the fine-tuning which can be found [here](https://huggingface.co/datasets/abisee/cnn_dailymail). Please note that we will use the *validation* split because we only want to run short fine-tuning.
#
# **NOTE:** for building the datset and downloading the pretrained model, ~4GB of space will be used.
#
# > **YOUR TASK:**
# >
# > Your job for this task is to set up the **GRPO-based** training with the package `trl`, i.e., the set up step 3 of [this](https://cdn.openai.com/instruction-following/draft-20220126f/methods.svg) figure. GRPO (Group Relative Policy Optimization) is an RL algorithm that was proposed by [Shao et al. (2024)](https://arxiv.org/pdf/2402.03300) for the DeepSeek math model.
# > 1. Please complete the code or insert comments what a particular line of code does below where the comments says "#### YOUR CODE / COMMENT HERE ####". For this and for answering the questions, you might need to dig a bit deeper into the working of GRPO, the algorithm that we are using for training. You can find relevant information on the implementation, e.g., [here](https://huggingface.co/docs/trl/main/en/grpo_trainer).
# > 2. To test your implementation, you can run the training for ~250 steps, but you are NOT required to train the full model since it will take too long. We will NOT be evaluating your submission based on the performance of the model.
# > 3. Answer the questions below.

# %%
# !pip install gcsfs==2025.3.0 fsspec==2025.3.0 accelerate==1.6.0 trl==0.17.0 evaluate rouge_score datasets
# Out:
# Requirement already satisfied: gcsfs==2025.3.0 in /usr/local/lib/python3.11/dist-packages (2025.3.0)
# Requirement already satisfied: fsspec==2025.3.0 in /usr/local/lib/python3.11/dist-packages (2025.3.0)
# Requirement already satisfied: accelerate==1.6.0 in /usr/local/lib/python3.11/dist-packages (1.6.0)
# Requirement already satisfied: trl==0.17.0 in /usr/local/lib/python3.11/dist-packages (0.17.0)
# Requirement already satisfied: evaluate in /usr/local/lib/python3.11/dist-packages (0.4.3)
# Requirement already satisfied: rouge_score in /usr/local/lib/python3.11/dist-packages (0.1.2)
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.6.0)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from gcsfs==2025.3.0) (3.11.15)
# Requirement already satisfied: decorator>4.1.2 in /usr/local/lib/python3.11/dist-packages (from gcsfs==2025.3.0) (4.4.2)
# Requirement already satisfied: google-auth>=1.2 in /usr/local/lib/python3.11/dist-packages (from gcsfs==2025.3.0) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib in /usr/local/lib/python3.11/dist-packages (from gcsfs==2025.3.0) (1.2.2)
# Requirement already satisfied: google-cloud-storage in /usr/local/lib/python3.11/dist-packages (from gcsfs==2025.3.0) (2.19.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from gcsfs==2025.3.0) (2.32.3)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.6.0) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.6.0) (24.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from accelerate==1.6.0) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from accelerate==1.6.0) (6.0.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.6.0) (2.6.0+cu124)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.6.0) (0.31.4)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from accelerate==1.6.0) (0.5.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from trl==0.17.0) (13.9.4)
# Requirement already satisfied: transformers>=4.46.0 in /usr/local/lib/python3.11/dist-packages (from trl==0.17.0) (4.52.2)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from evaluate) (2.2.2)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.11/dist-packages (from evaluate) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from evaluate) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.11/dist-packages (from evaluate) (0.70.15)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge_score) (3.9.1)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge_score) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->gcsfs==2025.3.0) (1.20.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.2->gcsfs==2025.3.0) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.2->gcsfs==2025.3.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=1.2->gcsfs==2025.3.0) (4.9.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.21.0->accelerate==1.6.0) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->gcsfs==2025.3.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->gcsfs==2025.3.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->gcsfs==2025.3.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->gcsfs==2025.3.0) (2025.4.26)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.0.0->accelerate==1.6.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.0.0->accelerate==1.6.0) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.0->trl==0.17.0) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.46.0->trl==0.17.0) (0.21.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib->gcsfs==2025.3.0) (2.0.0)
# Requirement already satisfied: google-api-core<3.0.0dev,>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->gcsfs==2025.3.0) (2.24.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->gcsfs==2025.3.0) (2.4.3)
# Requirement already satisfied: google-resumable-media>=2.7.2 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->gcsfs==2025.3.0) (2.7.2)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /usr/local/lib/python3.11/dist-packages (from google-cloud-storage->gcsfs==2025.3.0) (1.7.1)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge_score) (1.5.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->evaluate) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl==0.17.0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->trl==0.17.0) (2.19.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs==2025.3.0) (1.70.0)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<7.0.0,>=3.19.5 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs==2025.3.0) (5.29.4)
# Requirement already satisfied: proto-plus<2.0.0,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-api-core<3.0.0dev,>=2.15.0->google-cloud-storage->gcsfs==2025.3.0) (1.26.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->trl==0.17.0) (0.1.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=1.2->gcsfs==2025.3.0) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->gcsfs==2025.3.0) (3.2.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.0.0->accelerate==1.6.0) (3.0.2)
# ERROR: Operation cancelled by user
# ^C

# %%
# import libraries
import torch
from tqdm import tqdm
import pandas as pd

tqdm.pandas()

from transformers import AutoTokenizer
from datasets import load_dataset

from trl import (
    GRPOTrainer,
    GRPOConfig,
)
import evaluate

# %%
#### YOUR COMMENT HERE (what is the purpose of this code?) ####
config = GRPOConfig(
    #### YOUR COMMENT HERE (what is the meaning of each of the following parameters?) #####
    # the parameter learning_rate is associated with the
    learning_rate=1.41e-5,
    #### YOUR COMMENT HERE ####
    max_steps=250,
    #### YOUR COMMENT HERE ####
    per_device_train_batch_size=8,
    #### YOUR COMMENT HERE####
    num_generations=8,
    #### YOUR CODE HERE: set the number of overall training epochs to 1 ####
    num_train_epochs= 1,
    #### YOUR COMMENT HERE####
    logging_steps=1,
    #### YOUR COMMENT HERE####
    report_to="none",
)

# %% [markdown]
# We load the CNN dataset and truncate the texts to 512 tokens, because we don't want the training to be too memory heavy and we want to have "available" some tokens for the generation (GPT-2's context window size is 1024). Then we tokenize each text and pad it.

# %%
def build_dataset(
        model_name,
        dataset_name="abisee/cnn_dailymail"
    ):
    """
    Build dataset for training. This builds the dataset from `load_dataset`.

    Args:
        model_name (`str`):
            The name of the SFT model to be used, so that the matchin tokenizer can be loaded.
        dataset_name (`str`):
            The name of the dataset to be loaded.

    Returns:
        dataloader (`torch.utils.data.DataLoader`):
            The dataloader for the dataset.
    """
    tokenizer = AutoTokenizer.from_pretrained("gavin124/gpt2-finetuned-cnn-summarization-v2")
    tokenizer.pad_token = tokenizer.eos_token
    tokenizer.padding_side = 'left'
    # load the datasets
    ds = load_dataset(dataset_name, '1.0.0', split="validation")

    def tokenize(sample):
        sample["input_ids"] = tokenizer.encode(sample['id'],
            #### YOUR CODE HERE (hint: inspect the dataset to see how to access the input text)####,
            return_tensors="pt",
            max_length=512,
            truncation=True,
            padding="max_length"
        )
        # get the truncated natural language text, too
        sample["prompt"] = sample['article']#     tokenizer.encode(sample['article'],
                                            #return_tensors="pt",
                                            #max_length=512,
                                            #truncation=True,
                                            #padding="max_length") #### YOUR CODE HERE ####
        sample["ground_truth"] =sample['highlights']#tokenizer.encode(sample['highlights'],
                                #            return_tensors="pt",
                                #            max_length=512,
                                #            truncation=True,
                                #            padding="max_length")#### YOUR CODE HERE ####
#
        return sample

    ds = ds.map(tokenize, batched=False)
    ds.set_format(type="torch")
    return ds

# %%
# use tokenizer from HF named: "gavin124/gpt2-finetuned-cnn-summarization-v2"
# build the dataset
dataset =  build_dataset("gavin124/gpt2-finetuned-cnn-summarization-v2")

def collator(data):
    return dict((key, [d[key] for d in data]) for key in data[0])
# Out:
# Map:   0%|          | 0/13368 [00:00<?, ? examples/s]

# %%
# inspect a sample of the dataset
dataset[0]
# Out:
# {'article': '(CNN)Share, and your gift will be multiplied. That may sound like an esoteric adage, but when Zully Broussard selflessly decided to give one of her kidneys to a stranger, her generosity paired up with big data. It resulted in six patients receiving transplants. That surprised and wowed her. "I thought I was going to help this one person who I don\'t know, but the fact that so many people can have a life extension, that\'s pretty big," Broussard told CNN affiliate KGO. She may feel guided in her generosity by a higher power. "Thanks for all the support and prayers," a comment on a Facebook page in her name read. "I know this entire journey is much bigger than all of us. I also know I\'m just the messenger." CNN cannot verify the authenticity of the page. But the power that multiplied Broussard\'s gift was data processing of genetic profiles from donor-recipient pairs. It works on a simple swapping principle but takes it to a much higher level, according to California Pacific Medical Center in San Francisco. So high, that it is taking five surgeons, a covey of physician assistants, nurses and anesthesiologists, and more than 40 support staff to perform surgeries on 12 people. They are extracting six kidneys from donors and implanting them into six recipients. "The ages of the donors and recipients range from 26 to 70 and include three parent and child pairs, one sibling pair and one brother and sister-in-law pair," the medical center said in a statement. The chain of surgeries is to be wrapped up Friday. In late March, the medical center is planning to hold a reception for all 12 patients. Here\'s how the super swap works, according to California Pacific Medical Center. Say, your brother needs a kidney to save his life, or at least get off of dialysis, and you\'re willing to give him one of yours. But then it turns out that your kidney is not a match for him, and it\'s certain his body would reject it. Your brother can then get on a years-long waiting list for a kidney coming from an organ donor who died. Maybe that will work out -- or not, and time could run out for him. Alternatively, you and your brother could look for another recipient-living donor couple like yourselves -- say, two more siblings, where the donor\'s kidney isn\'t suited for his sister, the recipient. But maybe your kidney is a match for his sister, and his kidney is a match for your brother. So, you\'d do a swap. That\'s called a paired donation. It\'s a bit of a surgical square dance, where four people cross over partners temporarily and everybody goes home smiling. But instead of a square dance, Broussard\'s generous move set off a chain reaction, like dominoes falling. Her kidney, which was removed Thursday, went to a recipient, who was paired with a donor. That donor\'s kidney went to the next recipient, who was also paired with a donor, and so on. On Friday, the last donor will give a kidney to someone who has been biding time on one of those deceased donor lists to complete the chain. Such long-chain transplanting is rare. It\'s been done before, California Pacific Medical Center said in a statement, but matching up the people in the chain has been laborious and taken a long time. That changed when a computer programmer named David Jacobs received a kidney transplant. He had been waiting on a deceased donor list, when a live donor came along -- someone nice enough to give away a kidney to a stranger. Jacobs paid it forward with his programming skills, creating MatchGrid, a program that genetically matches up donor pairs or chains quickly. "When we did a five-way swap a few years ago, which was one of the largest, it took about three to four months. We did this in about three weeks," Jacobs said. But this chain wouldn\'t have worked so quickly without Broussard\'s generosity -- or may not have worked at all. "The significance of the altruistic donor is that it opens up possibilities for pairing compatible donors and recipients," said Dr. St ...
#  'highlights': 'Zully Broussard decided to give a kidney to a stranger . A new computer program helped her donation spur transplants for six kidney patients .',
#  'id': 'a4942dd663020ca54575471657a0af38d82897d6',
#  'input_ids': tensor([[50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,
#           50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256, 50256,    64,
#            2920,  3682,  1860,  2791,  1270,  1238,  6888, 45326,  2425,  2857,
#            1433,  3553,    64,    15,  1878,  2548,    67,    23,  2078,  5607,
#              67,    21]]),
#  'prompt': '(CNN)Share, and your gift will be multiplied. That may sound like an esoteric adage, but when Zully Broussard selflessly decided to give one of her kidneys to a stranger, her generosity paired up with big data. It resulted in six patients receiving transplants. That surprised and wowed her. "I thought I was going to help this one person who I don\'t know, but the fact that so many people can have a life extension, that\'s pretty big," Broussard told CNN affiliate KGO. She may feel guided in her generosity by a higher power. "Thanks for all the support and prayers," a comment on a Facebook page in her name read. "I know this entire journey is much bigger than all of us. I also know I\'m just the messenger." CNN cannot verify the authenticity of the page. But the power that multiplied Broussard\'s gift was data processing of genetic profiles from donor-recipient pairs. It works on a simple swapping principle but takes it to a much higher level, according to California Pacific Medical Center in San Francisco. So high, that it is taking five surgeons, a covey of physician assistants, nurses and anesthesiologists, and more than 40 support staff to perform surgeries on 12 people. They are extracting six kidneys from donors and implanting them into six recipients. "The ages of the donors and recipients range from 26 to 70 and include three parent and child pairs, one sibling pair and one brother and sister-in-law pair," the medical center said in a statement. The chain of surgeries is to be wrapped up Friday. In late March, the medical center is planning to hold a reception for all 12 patients. Here\'s how the super swap works, according to California Pacific Medical Center. Say, your brother needs a kidney to save his life, or at least get off of dialysis, and you\'re willing to give him one of yours. But then it turns out that your kidney is not a match for him, and it\'s certain his body would reject it. Your brother can then get on a years-long waiting list for a kidney coming from an organ donor who died. Maybe that will work out -- or not, and time could run out for him. Alternatively, you and your brother could look for another recipient-living donor couple like yourselves -- say, two more siblings, where the donor\'s kidney isn\'t suited for his sister, the recipient. But maybe your kidney is a match for his sister, and his kidney is a match for your brother. So, you\'d do a swap. That\'s called a paired donation. It\'s a bit of a surgical square dance, where four people cross over partners temporarily and everybody goes home smiling. But instead of a square dance, Broussard\'s generous move set off a chain reaction, like dominoes falling. Her kidney, which was removed Thursday, went to a recipient, who was paired with a donor. That donor\'s kidney went to the next recipient, who was also paired with a donor, and so on. On Friday, the last donor will give a kidney to someone who has been biding time on one of those deceased donor lists to complete the chain. Such long-chain transplanting is rare. It\'s been done before, California Pacific Medical Center said in a statement, but matching up the people in the chain has been laborious and taken a long time. That changed when a computer programmer named David Jacobs received a kidney transplant. He had been waiting on a deceased donor list, when a live donor came along -- someone nice enough to give away a kidney to a stranger. Jacobs paid it forward with his programming skills, creating MatchGrid, a program that genetically matches up donor pairs or chains quickly. "When we did a five-way swap a few years ago, which was one of the largest, it took about three to four months. We did this in about three weeks," Jacobs said. But this chain wouldn\'t have worked so quickly without Broussard\'s generosity -- or may not have worked at all. "The significance of the altruistic donor is that it opens up possibilities for pairing compatible donors and recipients," said Dr. Ste ...
#  'ground_truth': 'Zully Broussard decided to give a kidney to a stranger . A new computer program helped her donation spur transplants for six kidney patients .'}

# %% [markdown]
# We load the tokenizer corresponsing to the SFT GPT2 model that we already used above to pretokenize the dataset.

# %%
tokenizer = AutoTokenizer.from_pretrained("gavin124/gpt2-finetuned-cnn-summarization-v2")

tokenizer.padding_side='left'
tokenizer.pad_token = tokenizer.eos_token

# %% [markdown]
# Below, we define our custom reward function:

# %%
rouge = evaluate.load("rouge")

def reward_fn(**kwargs):
    output = kwargs["completions"]
    original_summary = kwargs["ground_truth"]

    scores = []
    for o, s in zip(output, original_summary):
        score = rouge.compute(predictions=[o.strip()], references=[s])["rouge1"]
        scores.append(torch.tensor(score))

    return scores

# %% [markdown]
# Nest, we set up the trainer:

# %%
#### YOUR COMMENTS BELOW (what are the congle lines doing?) ####
model="gavin124/gpt2-finetuned-cnn-summarization-v2"
grpo_trainer = GRPOTrainer(
    args=config,
    model="gavin124/gpt2-finetuned-cnn-summarization-v2",
    reward_funcs=reward_fn,
    processing_class=tokenizer,
    train_dataset=dataset,
)
grpo_trainer.train()
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (1660 > 1024). Running this sequence through the model will result in indexing errors
#     <div>
#
#       <progress value='81' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 81/250 07:55 < 16:57, 0.17 it/s, Epoch 0.01/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>-0.314400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.091200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.281500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.130200</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.179400</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.061900</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.318200</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.110700</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.260500</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>-0.261800</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>-0.125100</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.062400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.216300</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.025000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.008200</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.088600</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.005700</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.701600</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.178300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.243300</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.061900</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>-0.139400</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.268500</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>-0.113700</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>-0.105600</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.406600</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>-0.008300</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>-0.061700</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>2079604867072.000000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>-0.256600</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>-0.145000</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.189800</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>-0.024200</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.814800</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.193100</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.123100</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.090300</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.006300</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>-0.182200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>-0.188800</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.321900</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.078600</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>-0.121100</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>-0.142600</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.036500</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.117100</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>-0.105700</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>-0.013400</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>-0.003600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>-0.148800</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.070900</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.160600</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.412800</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.300400</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.093900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.287000</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.181400</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>-0.354300</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.272400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>-0.055600</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.246100</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.024400</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.364900</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.127300</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.375200</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>-0.060500</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>-0.034200</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>-0.027400</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.022300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.241000</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>-0.092600</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.355500</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>-0.088300</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.067300</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.146200</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.167700</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.038800</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.063100</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>-0.023100</td>
#     </tr>
#   </tbody>
# </table><p>
#     <div>
#
#       <progress value='250' max='250' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [250/250 23:15, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>-0.314400</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.091200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.281500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.130200</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.179400</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.061900</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.318200</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.110700</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.260500</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>-0.261800</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>-0.125100</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.062400</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.216300</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.025000</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.008200</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.088600</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.005700</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.701600</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.178300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.243300</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.061900</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>-0.139400</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.268500</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>-0.113700</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>-0.105600</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.406600</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>-0.008300</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>-0.061700</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>2079604867072.000000</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>-0.256600</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>-0.145000</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.189800</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>-0.024200</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.814800</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.193100</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>0.123100</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>0.090300</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>0.006300</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>-0.182200</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>-0.188800</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>0.321900</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>0.078600</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>-0.121100</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>-0.142600</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>0.036500</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>0.117100</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>-0.105700</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>-0.013400</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>-0.003600</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>-0.148800</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.070900</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>0.160600</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>0.412800</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>0.300400</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>0.093900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>0.287000</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>0.181400</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>-0.354300</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>0.272400</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>-0.055600</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>0.246100</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.024400</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>0.364900</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.127300</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>0.375200</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>-0.060500</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>-0.034200</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>-0.027400</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.022300</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>0.241000</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>-0.092600</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>0.355500</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>-0.088300</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>0.067300</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>0.146200</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>0.167700</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>0.038800</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.063100</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>-0.023100</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>-0.041200</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>0.314500</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>0.025100</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>-0.156100</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.129800</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>0.440200</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>0.046500</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>-0.065000</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>0.296400</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.108500</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>0.670800</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>-0.072200</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>-0.033100</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>-0.045800</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>-0.018500</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>0.054300</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.096300</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.373500</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>0.182500</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>-0.306500</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.038200</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>-0.022300</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>0.452100</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>-0.126900</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>0.113700</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>-0.027800</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>0.036800</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.002300</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>0.232800</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>0.166300</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>0.074900</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>-0.064700</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>0.048600</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>0.210000</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>-0.027700</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.028000</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>0.037300</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>-0.166700</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>-0.098200</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>-0.279400</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>0.029000</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>0.082300</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>-0.007500</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.078900</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.017600</td>
#     </tr>
#     <tr>
#       <td>125</td>
# TrainOutput(global_step=250, training_loss=8318419468.454778, metrics={'train_runtime': 1404.0302, 'train_samples_per_second': 1.424, 'train_steps_per_second': 0.178, 'total_flos': 0.0, 'train_loss': 8318419468.454778})

# %%
import matplotlib.pyplot as plt

# %%
grpo_trainer.state.log_history
# Out:
# [{'loss': -0.3144,
#   'grad_norm': 2.5340168476104736,
#   'learning_rate': 1.41e-05,
#   'num_tokens': 5198.0,
#   'completions/mean_length': 137.75,
#   'completions/min_length': 59.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.25,
#   'completions/mean_terminated_length': 98.33333587646484,
#   'completions/min_terminated_length': 59.0,
#   'completions/max_terminated_length': 175.0,
#   'rewards/reward_fn/mean': 0.20311149954795837,
#   'rewards/reward_fn/std': 0.04714175686240196,
#   'reward': 0.20311149954795837,
#   'reward_std': 0.04714176058769226,
#   'kl': 0.6024864315986633,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 7.480550568521843e-05,
#   'step': 1},
#  {'loss': 0.0912,
#   'grad_norm': 2.938589572906494,
#   'learning_rate': 1.40436e-05,
#   'num_tokens': 8960.0,
#   'completions/mean_length': 132.25,
#   'completions/min_length': 39.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.125,
#   'completions/mean_terminated_length': 114.5714340209961,
#   'completions/min_terminated_length': 39.0,
#   'completions/max_terminated_length': 185.0,
#   'rewards/reward_fn/mean': 0.20049312710762024,
#   'rewards/reward_fn/std': 0.06110464036464691,
#   'reward': 0.20049312710762024,
#   'reward_std': 0.061104632914066315,
#   'kl': 0.6394769549369812,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.00014961101137043686,
#   'step': 2},
#  {'loss': 0.2815,
#   'grad_norm': 2.4583497047424316,
#   'learning_rate': 1.39872e-05,
#   'num_tokens': 14672.0,
#   'completions/mean_length': 202.0,
#   'completions/min_length': 68.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.5,
#   'completions/mean_terminated_length': 148.0,
#   'completions/min_terminated_length': 68.0,
#   'completions/max_terminated_length': 205.0,
#   'rewards/reward_fn/mean': 0.15483358502388,
#   'rewards/reward_fn/std': 0.05122963339090347,
#   'reward': 0.15483358502388,
#   'reward_std': 0.05122963711619377,
#   'kl': 0.325666218996048,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0002244165170556553,
#   'step': 3},
#  {'loss': 0.1302,
#   'grad_norm': 1.5833011865615845,
#   'learning_rate': 1.39308e-05,
#   'num_tokens': 20432.0,
#   'completions/mean_length': 208.0,
#   'completions/min_length': 54.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.75,
#   'completions/mean_terminated_length': 64.0,
#   'completions/min_terminated_length': 54.0,
#   'completions/max_terminated_length': 74.0,
#   'rewards/reward_fn/mean': 0.15830621123313904,
#   'rewards/reward_fn/std': 0.033243127167224884,
#   'reward': 0.15830621123313904,
#   'reward_std': 0.033243127167224884,
#   'kl': 0.35703423619270325,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0002992220227408737,
#   'step': 4},
#  {'loss': 0.1794,
#   'grad_norm': 4.183939456939697,
#   'learning_rate': 1.38744e-05,
#   'num_tokens': 24513.0,
#   'completions/mean_length': 123.125,
#   'completions/min_length': 48.0,
#   'completions/max_length': 182.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 123.125,
#   'completions/min_terminated_length': 48.0,
#   'completions/max_terminated_length': 182.0,
#   'rewards/reward_fn/mean': 0.27122801542282104,
#   'rewards/reward_fn/std': 0.04778541997075081,
#   'reward': 0.27122801542282104,
#   'reward_std': 0.04778542369604111,
#   'kl': 0.7052252292633057,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.00037402752842609214,
#   'step': 5},
#  {'loss': 0.0619,
#   'grad_norm': 13.123722076416016,
#   'learning_rate': 1.3818e-05,
#   'num_tokens': 27916.0,
#   'completions/mean_length': 59.375,
#   'completions/min_length': 48.0,
#   'completions/max_length': 87.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 59.375,
#   'completions/min_terminated_length': 48.0,
#   'completions/max_terminated_length': 87.0,
#   'rewards/reward_fn/mean': 0.32773876190185547,
#   'rewards/reward_fn/std': 0.06435330212116241,
#   'reward': 0.32773876190185547,
#   'reward_std': 0.06435329467058182,
#   'kl': 1.4699726104736328,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0004488330341113106,
#   'step': 6},
#  {'loss': 0.3182,
#   'grad_norm': 1.9175653457641602,
#   'learning_rate': 1.37616e-05,
#   'num_tokens': 33687.0,
#   'completions/mean_length': 209.375,
#   'completions/min_length': 66.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.625,
#   'completions/mean_terminated_length': 131.6666717529297,
#   'completions/min_terminated_length': 66.0,
#   'completions/max_terminated_length': 252.0,
#   'rewards/reward_fn/mean': 0.13457518815994263,
#   'rewards/reward_fn/std': 0.03914549574255943,
#   'reward': 0.13457518815994263,
#   'reward_std': 0.039145492017269135,
#   'kl': 0.4323751628398895,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.000523638539796529,
#   'step': 7},
#  {'loss': 0.1107,
#   'grad_norm': 1.6205557584762573,
#   'learning_rate': 1.37052e-05,
#   'num_tokens': 39085.0,
#   'completions/mean_length': 162.75,
#   'completions/min_length': 55.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.375,
#   'completions/mean_terminated_length': 106.80000305175781,
#   'completions/min_terminated_length': 55.0,
#   'completions/max_terminated_length': 224.0,
#   'rewards/reward_fn/mean': 0.24751240015029907,
#   'rewards/reward_fn/std': 0.05944063514471054,
#   'reward': 0.24751240015029907,
#   'reward_std': 0.05944063887000084,
#   'kl': 0.47383448481559753,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0005984440454817474,
#   'step': 8},
#  {'loss': 0.2605,
#   'grad_norm': 6.348802089691162,
#   'learning_rate': 1.36488e-05,
#   'num_tokens': 43813.0,
#   'completions/mean_length': 79.0,
#   'completions/min_length': 44.0,
#   'completions/max_length': 214.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 79.0,
#   'completions/min_terminated_length': 44.0,
#   'completions/max_terminated_length': 214.0,
#   'rewards/reward_fn/mean': 0.18754658102989197,
#   'rewards/reward_fn/std': 0.04912581667304039,
#   'reward': 0.18754658102989197,
#   'reward_std': 0.04912581667304039,
#   'kl': 0.8448991179466248,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0006732495511669659,
#   'step': 9},
#  {'loss': -0.2618,
#   'grad_norm': 25.54414176940918,
#   'learning_rate': 1.35924e-05,
#   'num_tokens': 48836.0,
#   'completions/mean_length': 115.875,
#   'completions/min_length': 55.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.125,
#   'completions/mean_terminated_length': 95.85714721679688,
#   'completions/min_terminated_length': 55.0,
#   'completions/max_terminated_length': 177.0,
#   'rewards/reward_fn/mean': 0.24062882363796234,
#   'rewards/reward_fn/std': 0.06065848469734192,
#   'reward': 0.24062882363796234,
#   'reward_std': 0.06065848097205162,
#   'kl': 1.8572866916656494,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0007480550568521843,
#   'step': 10},
#  {'loss': -0.1251,
#   'grad_norm': 3.8877434730529785,
#   'learning_rate': 1.3536e-05,
#   'num_tokens': 53619.0,
#   'completions/mean_length': 85.875,
#   'completions/min_length': 49.0,
#   'completions/max_length': 186.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 85.875,
#   'completions/min_terminated_length': 49.0,
#   'completions/max_terminated_length': 186.0,
#   'rewards/reward_fn/mean': 0.2693895697593689,
#   'rewards/reward_fn/std': 0.04011008143424988,
#   'reward': 0.2693895697593689,
#   'reward_std': 0.04011008143424988,
#   'kl': 0.6119619607925415,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0008228605625374027,
#   'step': 11},
#  {'loss': 0.0624,
#   'grad_norm': 3.7049410343170166,
#   'learning_rate': 1.34796e-05,
#   'num_tokens': 57139.0,
#   'completions/mean_length': 86.0,
#   'completions/min_length': 36.0,
#   'completions/max_length': 173.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 86.0,
#   'completions/min_terminated_length': 36.0,
#   'completions/max_terminated_length': 173.0,
#   'rewards/reward_fn/mean': 0.28717339038848877,
#   'rewards/reward_fn/std': 0.04926580190658569,
#   'reward': 0.28717339038848877,
#   'reward_std': 0.04926580190658569,
#   'kl': 0.5620582103729248,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0008976660682226212,
#   'step': 12},
#  {'loss': 0.2163,
#   'grad_norm': 3.4704325199127197,
#   'learning_rate': 1.34232e-05,
#   'num_tokens': 62053.0,
#   'completions/mean_length': 102.25,
#   'completions/min_length': 39.0,
#   'completions/max_length': 242.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 102.25,
#   'completions/min_terminated_length': 39.0,
#   'completions/max_terminated_length': 242.0,
#   'rewards/reward_fn/mean': 0.1465880125761032,
#   'rewards/reward_fn/std': 0.038960058242082596,
#   'reward': 0.1465880125761032,
#   'reward_std': 0.038960058242082596,
#   'kl': 0.45800450444221497,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0009724715739078396,
#   'step': 13},
#  {'loss': 0.025,
#   'grad_norm': 3.741957426071167,
#   'learning_rate': 1.33668e-05,
#   'num_tokens': 67163.0,
#   'completions/mean_length': 126.75,
#   'completions/min_length': 67.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.125,
#   'completions/mean_terminated_length': 108.28572082519531,
#   'completions/min_terminated_length': 67.0,
#   'completions/max_terminated_length': 178.0,
#   'rewards/reward_fn/mean': 0.17291462421417236,
#   'rewards/reward_fn/std': 0.042365290224552155,
#   'reward': 0.17291462421417236,
#   'reward_std': 0.04236529394984245,
#   'kl': 0.9731703996658325,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.001047277079593058,
#   'step': 14},
#  {'loss': 0.0082,
#   'grad_norm': 4.596216678619385,
#   'learning_rate': 1.33104e-05,
#   'num_tokens': 71752.0,
#   'completions/mean_length': 61.625,
#   'completions/min_length': 47.0,
#   'completions/max_length': 77.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 61.625,
#   'completions/min_terminated_length': 47.0,
#   'completions/max_terminated_length': 77.0,
#   'rewards/reward_fn/mean': 0.25304868817329407,
#   'rewards/reward_fn/std': 0.05468621850013733,
#   'reward': 0.25304868817329407,
#   'reward_std': 0.054686225950717926,
#   'kl': 0.5540373921394348,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0011220825852782765,
#   'step': 15},
#  {'loss': 0.0886,
#   'grad_norm': 1.7517989873886108,
#   'learning_rate': 1.3254e-05,
#   'num_tokens': 77727.0,
#   'completions/mean_length': 234.875,
#   'completions/min_length': 124.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.5,
#   'completions/mean_terminated_length': 213.75,
#   'completions/min_terminated_length': 124.0,
#   'completions/max_terminated_length': 253.0,
#   'rewards/reward_fn/mean': 0.2132677584886551,
#   'rewards/reward_fn/std': 0.020378470420837402,
#   'reward': 0.2132677584886551,
#   'reward_std': 0.020378470420837402,
#   'kl': 0.27810773253440857,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0011968880909634949,
#   'step': 16},
#  {'loss': 0.0057,
#   'grad_norm': 8.535893440246582,
#   'learning_rate': 1.31976e-05,
#   'num_tokens': 80983.0,
#   'completions/mean_length': 53.0,
#   'completions/min_length': 41.0,
#   'completions/max_length': 70.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 53.0,
#   'completions/min_terminated_length': 41.0,
#   'completions/max_terminated_length': 70.0,
#   'rewards/reward_fn/mean': 0.33045506477355957,
#   'rewards/reward_fn/std': 0.06367094814777374,
#   'reward': 0.33045506477355957,
#   'reward_std': 0.06367094814777374,
#   'kl': 1.2277095317840576,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0012716935966487132,
#   'step': 17},
#  {'loss': 0.7016,
#   'grad_norm': 303.9645690917969,
#   'learning_rate': 1.31412e-05,
#   'num_tokens': 85769.0,
#   'completions/mean_length': 86.25,
#   'completions/min_length': 1.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.125,
#   'completions/mean_terminated_length': 62.000003814697266,
#   'completions/min_terminated_length': 1.0,
#   'completions/max_terminated_length': 170.0,
#   'rewards/reward_fn/mean': 0.21808379888534546,
#   'rewards/reward_fn/std': 0.10964059829711914,
#   'reward': 0.21808379888534546,
#   'reward_std': 0.10964059829711914,
#   'kl': 18.77764892578125,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0013464991023339318,
#   'step': 18},
#  {'loss': 0.1783,
#   'grad_norm': 1.8790382146835327,
#   'learning_rate': 1.30848e-05,
#   'num_tokens': 91102.0,
#   'completions/mean_length': 154.625,
#   'completions/min_length': 52.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.25,
#   'completions/mean_terminated_length': 120.83333587646484,
#   'completions/min_terminated_length': 52.0,
#   'completions/max_terminated_length': 216.0,
#   'rewards/reward_fn/mean': 0.11288771778345108,
#   'rewards/reward_fn/std': 0.03678020462393761,
#   'reward': 0.11288771778345108,
#   'reward_std': 0.03678020462393761,
#   'kl': 0.27559229731559753,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0014213046080191502,
#   'step': 19},
#  {'loss': 0.2433,
#   'grad_norm': 2.4077138900756836,
#   'learning_rate': 1.30284e-05,
#   'num_tokens': 95942.0,
#   'completions/mean_length': 93.0,
#   'completions/min_length': 56.0,
#   'completions/max_length': 204.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 93.0,
#   'completions/min_terminated_length': 56.0,
#   'completions/max_terminated_length': 204.0,
#   'rewards/reward_fn/mean': 0.2986104488372803,
#   'rewards/reward_fn/std': 0.08202174305915833,
#   'reward': 0.2986104488372803,
#   'reward_std': 0.08202175050973892,
#   'kl': 0.3905380070209503,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0014961101137043686,
#   'step': 20},
#  {'loss': 0.0619,
#   'grad_norm': 1.7273290157318115,
#   'learning_rate': 1.2972e-05,
#   'num_tokens': 102021.0,
#   'completions/mean_length': 247.875,
#   'completions/min_length': 191.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.875,
#   'completions/mean_terminated_length': 191.0,
#   'completions/min_terminated_length': 191.0,
#   'completions/max_terminated_length': 191.0,
#   'rewards/reward_fn/mean': 0.16269069910049438,
#   'rewards/reward_fn/std': 0.014303609728813171,
#   'reward': 0.16269069910049438,
#   'reward_std': 0.014303609728813171,
#   'kl': 0.32333365082740784,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0015709156193895871,
#   'step': 21},
#  {'loss': -0.1394,
#   'grad_norm': 4.549955368041992,
#   'learning_rate': 1.29156e-05,
#   'num_tokens': 106710.0,
#   'completions/mean_length': 74.125,
#   'completions/min_length': 45.0,
#   'completions/max_length': 120.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 74.125,
#   'completions/min_terminated_length': 45.0,
#   'completions/max_terminated_length': 120.0,
#   'rewards/reward_fn/mean': 0.24556253850460052,
#   'rewards/reward_fn/std': 0.06962554156780243,
#   'reward': 0.24556253850460052,
#   'reward_std': 0.06962554156780243,
#   'kl': 0.5551515817642212,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0016457211250748055,
#   'step': 22},
#  {'loss': 0.2685,
#   'grad_norm': 2.483456611633301,
#   'learning_rate': 1.28592e-05,
#   'num_tokens': 110396.0,
#   'completions/mean_length': 100.75,
#   'completions/min_length': 66.0,
#   'completions/max_length': 176.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 100.75,
#   'completions/min_terminated_length': 66.0,
#   'completions/max_terminated_length': 176.0,
#   'rewards/reward_fn/mean': 0.379521906375885,
#   'rewards/reward_fn/std': 0.05148888751864433,
#   'reward': 0.379521906375885,
#   'reward_std': 0.051488883793354034,
#   'kl': 0.37921953201293945,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0017205266307600239,
#   'step': 23},
#  {'loss': -0.1137,
#   'grad_norm': 2.773399591445923,
#   'learning_rate': 1.28028e-05,
#   'num_tokens': 115202.0,
#   'completions/mean_length': 103.75,
#   'completions/min_length': 49.0,
#   'completions/max_length': 160.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 103.75,
#   'completions/min_terminated_length': 49.0,
#   'completions/max_terminated_length': 160.0,
#   'rewards/reward_fn/mean': 0.28664112091064453,
#   'rewards/reward_fn/std': 0.0354144349694252,
#   'reward': 0.28664112091064453,
#   'reward_std': 0.0354144349694252,
#   'kl': 0.6106230020523071,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0017953321364452424,
#   'step': 24},
#  {'loss': -0.1056,
#   'grad_norm': 4.561266899108887,
#   'learning_rate': 1.27464e-05,
#   'num_tokens': 117711.0,
#   'completions/mean_length': 54.625,
#   'completions/min_length': 35.0,
#   'completions/max_length': 78.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 54.625,
#   'completions/min_terminated_length': 35.0,
#   'completions/max_terminated_length': 78.0,
#   'rewards/reward_fn/mean': 0.2853979766368866,
#   'rewards/reward_fn/std': 0.07960415631532669,
#   'reward': 0.2853979766368866,
#   'reward_std': 0.0796041414141655,
#   'kl': 0.7692909240722656,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0018701376421304608,
#   'step': 25},
#  {'loss': 0.4066,
#   'grad_norm': 4.376504898071289,
#   'learning_rate': 1.269e-05,
#   'num_tokens': 123163.0,
#   'completions/mean_length': 169.5,
#   'completions/min_length': 77.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.25,
#   'completions/mean_terminated_length': 140.6666717529297,
#   'completions/min_terminated_length': 77.0,
#   'completions/max_terminated_length': 217.0,
#   'rewards/reward_fn/mean': 0.16473346948623657,
#   'rewards/reward_fn/std': 0.05211656913161278,
#   'reward': 0.16473346948623657,
#   'reward_std': 0.05211656913161278,
#   'kl': 1.1913832426071167,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0019449431478156792,
#   'step': 26},
#  {'loss': -0.0083,
#   'grad_norm': 3.1470389366149902,
#   'learning_rate': 1.26336e-05,
#   'num_tokens': 128180.0,
#   'completions/mean_length': 115.125,
#   'completions/min_length': 65.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.125,
#   'completions/mean_terminated_length': 95.00000762939453,
#   'completions/min_terminated_length': 65.0,
#   'completions/max_terminated_length': 149.0,
#   'rewards/reward_fn/mean': 0.24840158224105835,
#   'rewards/reward_fn/std': 0.05058785900473595,
#   'reward': 0.24840158224105835,
#   'reward_std': 0.05058785527944565,
#   'kl': 0.46400293707847595,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0020197486535008975,
#   'step': 27},
#  {'loss': -0.0617,
#   'grad_norm': 3.097418785095215,
#   'learning_rate': 1.25772e-05,
#   'num_tokens': 132799.0,
#   'completions/mean_length': 65.375,
#   'completions/min_length': 51.0,
#   'completions/max_length': 83.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 65.375,
#   'completions/min_terminated_length': 51.0,
#   'completions/max_terminated_length': 83.0,
#   'rewards/reward_fn/mean': 0.21956922113895416,
#   'rewards/reward_fn/std': 0.05224134773015976,
#   'reward': 0.21956922113895416,
#   'reward_std': 0.05224134773015976,
#   'kl': 0.39058786630630493,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.002094554159186116,
#   'step': 28},
#  {'loss': 2079604867072.0,
#   'grad_norm': 2945818478772224.0,
#   'learning_rate': 1.25208e-05,
#   'num_tokens': 137763.0,
#   'completions/mean_length': 108.5,
#   'completions/min_length': 46.0,
#   'completions/max_length': 213.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 108.5,
#   'completions/min_terminated_length': 46.0,
#   'completions/max_terminated_length': 213.0,
#   'rewards/reward_fn/mean': 0.21886906027793884,
#   'rewards/reward_fn/std': 0.04896355792880058,
#   'reward': 0.21886906027793884,
#   'reward_std': 0.048963550478219986,
#   'kl': 51990121938944.0,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0021693596648713347,
#   'step': 29},
#  {'loss': -0.2566,
#   'grad_norm': 2.675966739654541,
#   'learning_rate': 1.24644e-05,
#   'num_tokens': 142813.0,
#   'completions/mean_length': 119.25,
#   'completions/min_length': 54.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.125,
#   'completions/mean_terminated_length': 99.71428680419922,
#   'completions/min_terminated_length': 54.0,
#   'completions/max_terminated_length': 204.0,
#   'rewards/reward_fn/mean': 0.23394468426704407,
#   'rewards/reward_fn/std': 0.05557584390044212,
#   'reward': 0.23394468426704407,
#   'reward_std': 0.055575836449861526,
#   'kl': 0.5698077082633972,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.002244165170556553,
#   'step': 30},
#  {'loss': -0.145,
#   'grad_norm': 2.7660229206085205,
#   'learning_rate': 1.2408e-05,
#   'num_tokens': 147542.0,
#   'completions/mean_length': 79.125,
#   'completions/min_length': 50.0,
#   'completions/max_length': 109.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 79.125,
#   'completions/min_terminated_length': 50.0,
#   'completions/max_terminated_length': 109.0,
#   'rewards/reward_fn/mean': 0.2342749536037445,
#   'rewards/reward_fn/std': 0.05100318789482117,
#   'reward': 0.2342749536037445,
#   'reward_std': 0.05100318044424057,
#   'kl': 0.3303152620792389,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0023189706762417714,
#   'step': 31},
#  {'loss': 0.1898,
#   'grad_norm': 1.554413080215454,
#   'learning_rate': 1.23516e-05,
#   'num_tokens': 153398.0,
#   'completions/mean_length': 220.0,
#   'completions/min_length': 81.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.75,
#   'completions/mean_terminated_length': 112.0,
#   'completions/min_terminated_length': 81.0,
#   'completions/max_terminated_length': 143.0,
#   'rewards/reward_fn/mean': 0.12999123334884644,
#   'rewards/reward_fn/std': 0.0179037693887949,
#   'reward': 0.12999123334884644,
#   'reward_std': 0.01790376752614975,
#   'kl': 0.262117475271225,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0023937761819269898,
#   'step': 32},
#  {'loss': -0.0242,
#   'grad_norm': 3.890427827835083,
#   'learning_rate': 1.22952e-05,
#   'num_tokens': 157913.0,
#   'completions/mean_length': 52.375,
#   'completions/min_length': 36.0,
#   'completions/max_length': 93.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 52.375,
#   'completions/min_terminated_length': 36.0,
#   'completions/max_terminated_length': 93.0,
#   'rewards/reward_fn/mean': 0.22152432799339294,
#   'rewards/reward_fn/std': 0.053508177399635315,
#   'reward': 0.22152432799339294,
#   'reward_std': 0.053508173674345016,
#   'kl': 0.7924337983131409,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.002468581687612208,
#   'step': 33},
#  {'loss': 0.8148,
#   'grad_norm': 167.35403442382812,
#   'learning_rate': 1.22388e-05,
#   'num_tokens': 162567.0,
#   'completions/mean_length': 69.75,
#   'completions/min_length': 56.0,
#   'completions/max_length': 83.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 69.75,
#   'completions/min_terminated_length': 56.0,
#   'completions/max_terminated_length': 83.0,
#   'rewards/reward_fn/mean': 0.2140151858329773,
#   'rewards/reward_fn/std': 0.04333971068263054,
#   'reward': 0.2140151858329773,
#   'reward_std': 0.04333971068263054,
#   'kl': 22.02985954284668,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0025433871932974265,
#   'step': 34},
#  {'loss': 0.1931,
#   'grad_norm': 193.13743591308594,
#   'learning_rate': 1.21824e-05,
#   'num_tokens': 167328.0,
#   'completions/mean_length': 83.125,
#   'completions/min_length': 44.0,
#   'completions/max_length': 172.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 83.125,
#   'completions/min_terminated_length': 44.0,
#   'completions/max_terminated_length': 172.0,
#   'rewards/reward_fn/mean': 0.2125791609287262,
#   'rewards/reward_fn/std': 0.056043755263090134,
#   'reward': 0.2125791609287262,
#   'reward_std': 0.056043751537799835,
#   'kl': 10.761550903320312,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0026181926989826453,
#   'step': 35},
#  {'loss': 0.1231,
#   'grad_norm': 5.013141632080078,
#   'learning_rate': 1.2126e-05,
#   'num_tokens': 171803.0,
#   'completions/mean_length': 57.375,
#   'completions/min_length': 30.0,
#   'completions/max_length': 80.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 57.375,
#   'completions/min_terminated_length': 30.0,
#   'completions/max_terminated_length': 80.0,
#   'rewards/reward_fn/mean': 0.33373379707336426,
#   'rewards/reward_fn/std': 0.1072109118103981,
#   'reward': 0.33373379707336426,
#   'reward_std': 0.1072109118103981,
#   'kl': 0.784315824508667,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0026929982046678637,
#   'step': 36},
#  {'loss': 0.0903,
#   'grad_norm': 5.5033369064331055,
#   'learning_rate': 1.20696e-05,
#   'num_tokens': 175753.0,
#   'completions/mean_length': 67.75,
#   'completions/min_length': 49.0,
#   'completions/max_length': 101.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 67.75,
#   'completions/min_terminated_length': 49.0,
#   'completions/max_terminated_length': 101.0,
#   'rewards/reward_fn/mean': 0.28540170192718506,
#   'rewards/reward_fn/std': 0.07517130672931671,
#   'reward': 0.28540170192718506,
#   'reward_std': 0.07517130672931671,
#   'kl': 0.9194909930229187,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.002767803710353082,
#   'step': 37},
#  {'loss': 0.0063,
#   'grad_norm': 7.666065692901611,
#   'learning_rate': 1.20132e-05,
#   'num_tokens': 179108.0,
#   'completions/mean_length': 69.375,
#   'completions/min_length': 49.0,
#   'completions/max_length': 105.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 69.375,
#   'completions/min_terminated_length': 49.0,
#   'completions/max_terminated_length': 105.0,
#   'rewards/reward_fn/mean': 0.22809529304504395,
#   'rewards/reward_fn/std': 0.07332302629947662,
#   'reward': 0.22809529304504395,
#   'reward_std': 0.07332301884889603,
#   'kl': 1.4902993440628052,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0028426092160383004,
#   'step': 38},
#  {'loss': -0.1822,
#   'grad_norm': 3.9816901683807373,
#   'learning_rate': 1.19568e-05,
#   'num_tokens': 183939.0,
#   'completions/mean_length': 91.875,
#   'completions/min_length': 55.0,
#   'completions/max_length': 190.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 91.875,
#   'completions/min_terminated_length': 55.0,
#   'completions/max_terminated_length': 190.0,
#   'rewards/reward_fn/mean': 0.2752149701118469,
#   'rewards/reward_fn/std': 0.0421319305896759,
#   'reward': 0.2752149701118469,
#   'reward_std': 0.042131923139095306,
#   'kl': 0.6689863204956055,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0029174147217235187,
#   'step': 39},
#  {'loss': -0.1888,
#   'grad_norm': 1.8438878059387207,
#   'learning_rate': 1.19004e-05,
#   'num_tokens': 189330.0,
#   'completions/mean_length': 161.875,
#   'completions/min_length': 50.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.5,
#   'completions/mean_terminated_length': 67.75,
#   'completions/min_terminated_length': 50.0,
#   'completions/max_terminated_length': 75.0,
#   'rewards/reward_fn/mean': 0.2693242132663727,
#   'rewards/reward_fn/std': 0.05456256866455078,
#   'reward': 0.2693242132663727,
#   'reward_std': 0.05456256866455078,
#   'kl': 0.41431087255477905,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.002992220227408737,
#   'step': 40},
#  {'loss': 0.3219,
#   'grad_norm': 2.6411964893341064,
#   'learning_rate': 1.1844e-05,
#   'num_tokens': 194443.0,
#   'completions/mean_length': 127.125,
#   'completions/min_length': 63.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.125,
#   'completions/mean_terminated_length': 108.71428680419922,
#   'completions/min_terminated_length': 63.0,
#   'completions/max_terminated_length': 178.0,
#   'rewards/reward_fn/mean': 0.1979697346687317,
#   'rewards/reward_fn/std': 0.03488079085946083,
#   'reward': 0.1979697346687317,
#   'reward_std': 0.03488079085946083,
#   'kl': 0.4634755849838257,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.003067025733093956,
#   'step': 41},
#  {'loss': 0.0786,
#   'grad_norm': 6.165004253387451,
#   'learning_rate': 1.17876e-05,
#   'num_tokens': 199097.0,
#   'completions/mean_length': 73.75,
#   'completions/min_length': 61.0,
#   'completions/max_length': 96.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 73.75,
#   'completions/min_terminated_length': 61.0,
#   'completions/max_terminated_length': 96.0,
#   'rewards/reward_fn/mean': 0.266712486743927,
#   'rewards/reward_fn/std': 0.046171702444553375,
#   'reward': 0.266712486743927,
#   'reward_std': 0.04617169499397278,
#   'kl': 1.0094693899154663,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0031418312387791743,
#   'step': 42},
#  {'loss': -0.1211,
#   'grad_norm': 3.269362688064575,
#   'learning_rate': 1.17312e-05,
#   'num_tokens': 204212.0,
#   'completions/mean_length': 127.375,
#   'completions/min_length': 46.0,
#   'completions/max_length': 216.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 127.375,
#   'completions/min_terminated_length': 46.0,
#   'completions/max_terminated_length': 216.0,
#   'rewards/reward_fn/mean': 0.2813938856124878,
#   'rewards/reward_fn/std': 0.04164852201938629,
#   'reward': 0.2813938856124878,
#   'reward_std': 0.04164851829409599,
#   'kl': 0.41869327425956726,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0032166367444643926,
#   'step': 43},
#  {'loss': -0.1426,
#   'grad_norm': 9.388655662536621,
#   'learning_rate': 1.16748e-05,
#   'num_tokens': 208985.0,
#   'completions/mean_length': 84.625,
#   'completions/min_length': 29.0,
#   'completions/max_length': 126.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 84.625,
#   'completions/min_terminated_length': 29.0,
#   'completions/max_terminated_length': 126.0,
#   'rewards/reward_fn/mean': 0.18675732612609863,
#   'rewards/reward_fn/std': 0.029743025079369545,
#   'reward': 0.18675732612609863,
#   'reward_std': 0.029743026942014694,
#   'kl': 1.4943028688430786,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.003291442250149611,
#   'step': 44},
#  {'loss': 0.0365,
#   'grad_norm': 4.433884143829346,
#   'learning_rate': 1.16184e-05,
#   'num_tokens': 212498.0,
#   'completions/mean_length': 60.125,
#   'completions/min_length': 41.0,
#   'completions/max_length': 93.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 60.125,
#   'completions/min_terminated_length': 41.0,
#   'completions/max_terminated_length': 93.0,
#   'rewards/reward_fn/mean': 0.33483296632766724,
#   'rewards/reward_fn/std': 0.1127125546336174,
#   'reward': 0.33483296632766724,
#   'reward_std': 0.112712562084198,
#   'kl': 0.9072121977806091,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0033662477558348293,
#   'step': 45},
#  {'loss': 0.1171,
#   'grad_norm': 5.52113676071167,
#   'learning_rate': 1.1562e-05,
#   'num_tokens': 217723.0,
#   'completions/mean_length': 141.125,
#   'completions/min_length': 79.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.125,
#   'completions/mean_terminated_length': 124.71429443359375,
#   'completions/min_terminated_length': 79.0,
#   'completions/max_terminated_length': 230.0,
#   'rewards/reward_fn/mean': 0.20165498554706573,
#   'rewards/reward_fn/std': 0.04120099917054176,
#   'reward': 0.20165498554706573,
#   'reward_std': 0.04120099917054176,
#   'kl': 0.6724833250045776,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0034410532615200477,
#   'step': 46},
#  {'loss': -0.1057,
#   'grad_norm': 3.723524808883667,
#   'learning_rate': 1.15056e-05,
#   'num_tokens': 222400.0,
#   'completions/mean_length': 72.625,
#   'completions/min_length': 57.0,
#   'completions/max_length': 94.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 72.625,
#   'completions/min_terminated_length': 57.0,
#   'completions/max_terminated_length': 94.0,
#   'rewards/reward_fn/mean': 0.2102774828672409,
#   'rewards/reward_fn/std': 0.08490224182605743,
#   'reward': 0.2102774828672409,
#   'reward_std': 0.08490223437547684,
#   'kl': 0.6120610237121582,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0035158587672052665,
#   'step': 47},
#  {'loss': -0.0134,
#   'grad_norm': 2.833678722381592,
#   'learning_rate': 1.14492e-05,
#   'num_tokens': 227050.0,
#   'completions/mean_length': 69.25,
#   'completions/min_length': 47.0,
#   'completions/max_length': 108.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 69.25,
#   'completions/min_terminated_length': 47.0,
#   'completions/max_terminated_length': 108.0,
#   'rewards/reward_fn/mean': 0.2444612979888916,
#   'rewards/reward_fn/std': 0.05606884881854057,
#   'reward': 0.2444612979888916,
#   'reward_std': 0.056068841367959976,
#   'kl': 0.34832432866096497,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.003590664272890485,
#   'step': 48},
#  {'loss': -0.0036,
#   'grad_norm': 2.625251293182373,
#   'learning_rate': 1.13928e-05,
#   'num_tokens': 231970.0,
#   'completions/mean_length': 103.0,
#   'completions/min_length': 45.0,
#   'completions/max_length': 153.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 103.0,
#   'completions/min_terminated_length': 45.0,
#   'completions/max_terminated_length': 153.0,
#   'rewards/reward_fn/mean': 0.2614022195339203,
#   'rewards/reward_fn/std': 0.08362612128257751,
#   'reward': 0.2614022195339203,
#   'reward_std': 0.08362612128257751,
#   'kl': 0.5664966702461243,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0036654697785757032,
#   'step': 49},
#  {'loss': -0.1488,
#   'grad_norm': 2.5000123977661133,
#   'learning_rate': 1.13364e-05,
#   'num_tokens': 236789.0,
#   'completions/mean_length': 90.375,
#   'completions/min_length': 55.0,
#   'completions/max_length': 160.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 90.375,
#   'completions/min_terminated_length': 55.0,
#   'completions/max_terminated_length': 160.0,
#   'rewards/reward_fn/mean': 0.21102996170520782,
#   'rewards/reward_fn/std': 0.050570156425237656,
#   'reward': 0.21102996170520782,
#   'reward_std': 0.05057014152407646,
#   'kl': 0.4397469758987427,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0037402752842609216,
#   'step': 50},
#  {'loss': 0.0709,
#   'grad_norm': 87.11061096191406,
#   'learning_rate': 1.128e-05,
#   'num_tokens': 241461.0,
#   'completions/mean_length': 72.0,
#   'completions/min_length': 43.0,
#   'completions/max_length': 95.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 72.0,
#   'completions/min_terminated_length': 43.0,
#   'completions/max_terminated_length': 95.0,
#   'rewards/reward_fn/mean': 0.24496260285377502,
#   'rewards/reward_fn/std': 0.06682228296995163,
#   'reward': 0.24496260285377502,
#   'reward_std': 0.06682228296995163,
#   'kl': 4.865169525146484,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.00381508078994614,
#   'step': 51},
#  {'loss': 0.1606,
#   'grad_norm': 2.22463059425354,
#   'learning_rate': 1.12236e-05,
#   'num_tokens': 246342.0,
#   'completions/mean_length': 98.125,
#   'completions/min_length': 30.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.125,
#   'completions/mean_terminated_length': 75.5714340209961,
#   'completions/min_terminated_length': 30.0,
#   'completions/max_terminated_length': 158.0,
#   'rewards/reward_fn/mean': 0.20124556124210358,
#   'rewards/reward_fn/std': 0.07496647536754608,
#   'reward': 0.20124556124210358,
#   'reward_std': 0.07496647536754608,
#   'kl': 0.3891247808933258,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.0038898862956313583,
#   'step': 52},
#  {'loss': 0.4128,
#   'grad_norm': 61.21229553222656,
#   'learning_rate': 1.11672e-05,
#   'num_tokens': 251441.0,
#   'completions/mean_length': 125.375,
#   'completions/min_length': 51.0,
#   'completions/max_length': 227.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 125.375,
#   'completions/min_terminated_length': 51.0,
#   'completions/max_terminated_length': 227.0,
#   'rewards/reward_fn/mean': 0.18428903818130493,
#   'rewards/reward_fn/std': 0.04426949471235275,
#   'reward': 0.18428903818130493,
#   'reward_std': 0.04426949843764305,
#   'kl': 7.3303093910217285,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.003964691801316577,
#   'step': 53},
#  {'loss': 0.3004,
#   'grad_norm': 1.8037866353988647,
#   'learning_rate': 1.11108e-05,
#   'num_tokens': 256755.0,
#   'completions/mean_length': 152.25,
#   'completions/min_length': 79.0,
#   'completions/max_length': 248.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 152.25,
#   'completions/min_terminated_length': 79.0,
#   'completions/max_terminated_length': 248.0,
#   'rewards/reward_fn/mean': 0.20065626502037048,
#   'rewards/reward_fn/std': 0.06666421890258789,
#   'reward': 0.20065626502037048,
#   'reward_std': 0.06666421890258789,
#   'kl': 0.4100044369697571,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.004039497307001795,
#   'step': 54},
#  {'loss': 0.0939,
#   'grad_norm': 2.817631721496582,
#   'learning_rate': 1.10544e-05,
#   'num_tokens': 261526.0,
#   'completions/mean_length': 84.375,
#   'completions/min_length': 57.0,
#   'completions/max_length': 103.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 84.375,
#   'completions/min_terminated_length': 57.0,
#   'completions/max_terminated_length': 103.0,
#   'rewards/reward_fn/mean': 0.18736527860164642,
#   'rewards/reward_fn/std': 0.05074397101998329,
#   'reward': 0.18736527860164642,
#   'reward_std': 0.05074397101998329,
#   'kl': 0.38159558176994324,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.004114302812687013,
#   'step': 55},
#  {'loss': 0.287,
#   'grad_norm': 3.454214334487915,
#   'learning_rate': 1.0998e-05,
#   'num_tokens': 266952.0,
#   'completions/mean_length': 166.25,
#   'completions/min_length': 81.0,
#   'completions/max_length': 245.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 166.25,
#   'completions/min_terminated_length': 81.0,
#   'completions/max_terminated_length': 245.0,
#   'rewards/reward_fn/mean': 0.2285034954547882,
#   'rewards/reward_fn/std': 0.05421920865774155,
#   'reward': 0.2285034954547882,
#   'reward_std': 0.054219212383031845,
#   'kl': 0.9474610090255737,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.004189108318372232,
#   'step': 56},
#  {'loss': 0.1814,
#   'grad_norm': 3.082214593887329,
#   'learning_rate': 1.09416e-05,
#   'num_tokens': 271844.0,
#   'completions/mean_length': 99.5,
#   'completions/min_length': 64.0,
#   'completions/max_length': 150.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 99.5,
#   'completions/min_terminated_length': 64.0,
#   'completions/max_terminated_length': 150.0,
#   'rewards/reward_fn/mean': 0.22474835813045502,
#   'rewards/reward_fn/std': 0.029987987130880356,
#   'reward': 0.22474835813045502,
#   'reward_std': 0.029987983405590057,
#   'kl': 0.4983150064945221,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.004263913824057451,
#   'step': 57},
#  {'loss': -0.3543,
#   'grad_norm': 2.897010564804077,
#   'learning_rate': 1.08852e-05,
#   'num_tokens': 276617.0,
#   'completions/mean_length': 84.625,
#   'completions/min_length': 35.0,
#   'completions/max_length': 153.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 84.625,
#   'completions/min_terminated_length': 35.0,
#   'completions/max_terminated_length': 153.0,
#   'rewards/reward_fn/mean': 0.301322877407074,
#   'rewards/reward_fn/std': 0.05304330214858055,
#   'reward': 0.301322877407074,
#   'reward_std': 0.05304330214858055,
#   'kl': 0.35189899802207947,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.004338719329742669,
#   'step': 58},
#  {'loss': 0.2724,
#   'grad_norm': 3.2677197456359863,
#   'learning_rate': 1.08288e-05,
#   'num_tokens': 282236.0,
#   'completions/mean_length': 190.375,
#   'completions/min_length': 100.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.375,
#   'completions/mean_terminated_length': 151.0,
#   'completions/min_terminated_length': 100.0,
#   'completions/max_terminated_length': 215.0,
#   'rewards/reward_fn/mean': 0.24680596590042114,
#   'rewards/reward_fn/std': 0.07042393833398819,
#   'reward': 0.24680596590042114,
#   'reward_std': 0.07042393833398819,
#   'kl': 0.5736597180366516,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.004413524835427888,
#   'step': 59},
#  {'loss': -0.0556,
#   'grad_norm': 4.748287200927734,
#   'learning_rate': 1.07724e-05,
#   'num_tokens': 287116.0,
#   'completions/mean_length': 98.0,
#   'completions/min_length': 64.0,
#   'completions/max_length': 136.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 98.0,
#   'completions/min_terminated_length': 64.0,
#   'completions/max_terminated_length': 136.0,
#   'rewards/reward_fn/mean': 0.2170330435037613,
#   'rewards/reward_fn/std': 0.04654813930392265,
#   'reward': 0.2170330435037613,
#   'reward_std': 0.04654814302921295,
#   'kl': 0.8031740188598633,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.004488330341113106,
#   'step': 60},
#  {'loss': 0.2461,
#   'grad_norm': 12.522286415100098,
#   'learning_rate': 1.0716e-05,
#   'num_tokens': 292030.0,
#   'completions/mean_length': 102.25,
#   'completions/min_length': 49.0,
#   'completions/max_length': 230.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 102.25,
#   'completions/min_terminated_length': 49.0,
#   'completions/max_terminated_length': 230.0,
#   'rewards/reward_fn/mean': 0.2745593786239624,
#   'rewards/reward_fn/std': 0.06793385744094849,
#   'reward': 0.2745593786239624,
#   'reward_std': 0.06793385744094849,
#   'kl': 2.0129382610321045,
#   'clip_ratio/low_mean': 0.0,
# ...
#   'epoch': 0.01720526630760024,
#   'step': 230},
#  {'loss': 0.1095,
#   'grad_norm': 2.7580649852752686,
#   'learning_rate': 1.128e-06,
#   'num_tokens': 1075749.0,
#   'completions/mean_length': 99.25,
#   'completions/min_length': 51.0,
#   'completions/max_length': 138.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 99.25,
#   'completions/min_terminated_length': 51.0,
#   'completions/max_terminated_length': 138.0,
#   'rewards/reward_fn/mean': 0.24305689334869385,
#   'rewards/reward_fn/std': 0.05241851881146431,
#   'reward': 0.24305689334869385,
#   'reward_std': 0.05241851881146431,
#   'kl': 0.5189744830131531,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.017280071813285457,
#   'step': 231},
#  {'loss': -0.0889,
#   'grad_norm': 3.1393015384674072,
#   'learning_rate': 1.0716e-06,
#   'num_tokens': 1080437.0,
#   'completions/mean_length': 74.0,
#   'completions/min_length': 29.0,
#   'completions/max_length': 105.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 74.0,
#   'completions/min_terminated_length': 29.0,
#   'completions/max_terminated_length': 105.0,
#   'rewards/reward_fn/mean': 0.25043854117393494,
#   'rewards/reward_fn/std': 0.05318475514650345,
#   'reward': 0.25043854117393494,
#   'reward_std': 0.05318475514650345,
#   'kl': 0.5981394052505493,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.017354877318970677,
#   'step': 232},
#  {'loss': 0.2139,
#   'grad_norm': 2.822385549545288,
#   'learning_rate': 1.0152e-06,
#   'num_tokens': 1085314.0,
#   'completions/mean_length': 97.625,
#   'completions/min_length': 56.0,
#   'completions/max_length': 168.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 97.625,
#   'completions/min_terminated_length': 56.0,
#   'completions/max_terminated_length': 168.0,
#   'rewards/reward_fn/mean': 0.23451650142669678,
#   'rewards/reward_fn/std': 0.030548904091119766,
#   'reward': 0.23451650142669678,
#   'reward_std': 0.030548902228474617,
#   'kl': 0.504432737827301,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.017429682824655894,
#   'step': 233},
#  {'loss': 0.0348,
#   'grad_norm': 2.630189895629883,
#   'learning_rate': 9.588e-07,
#   'num_tokens': 1089981.0,
#   'completions/mean_length': 71.375,
#   'completions/min_length': 48.0,
#   'completions/max_length': 85.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 71.375,
#   'completions/min_terminated_length': 48.0,
#   'completions/max_terminated_length': 85.0,
#   'rewards/reward_fn/mean': 0.23202207684516907,
#   'rewards/reward_fn/std': 0.02261059358716011,
#   'reward': 0.23202207684516907,
#   'reward_std': 0.022610584273934364,
#   'kl': 0.44047608971595764,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.017504488330341114,
#   'step': 234},
#  {'loss': -0.1022,
#   'grad_norm': 2.7031149864196777,
#   'learning_rate': 9.024e-07,
#   'num_tokens': 1094694.0,
#   'completions/mean_length': 77.125,
#   'completions/min_length': 27.0,
#   'completions/max_length': 103.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 77.125,
#   'completions/min_terminated_length': 27.0,
#   'completions/max_terminated_length': 103.0,
#   'rewards/reward_fn/mean': 0.2772994637489319,
#   'rewards/reward_fn/std': 0.0636478140950203,
#   'reward': 0.2772994637489319,
#   'reward_std': 0.0636478140950203,
#   'kl': 0.5629260540008545,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.01757929383602633,
#   'step': 235},
#  {'loss': -0.0198,
#   'grad_norm': 3.103327989578247,
#   'learning_rate': 8.46e-07,
#   'num_tokens': 1099332.0,
#   'completions/mean_length': 67.75,
#   'completions/min_length': 43.0,
#   'completions/max_length': 79.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 67.75,
#   'completions/min_terminated_length': 43.0,
#   'completions/max_terminated_length': 79.0,
#   'rewards/reward_fn/mean': 0.21168862283229828,
#   'rewards/reward_fn/std': 0.027622314170002937,
#   'reward': 0.21168862283229828,
#   'reward_std': 0.027622317895293236,
#   'kl': 0.40607020258903503,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.01765409934171155,
#   'step': 236},
#  {'loss': 0.1421,
#   'grad_norm': 2.9621946811676025,
#   'learning_rate': 7.896e-07,
#   'num_tokens': 1103959.0,
#   'completions/mean_length': 66.375,
#   'completions/min_length': 44.0,
#   'completions/max_length': 88.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 66.375,
#   'completions/min_terminated_length': 44.0,
#   'completions/max_terminated_length': 88.0,
#   'rewards/reward_fn/mean': 0.30148428678512573,
#   'rewards/reward_fn/std': 0.06789509207010269,
#   'reward': 0.30148428678512573,
#   'reward_std': 0.06789509207010269,
#   'kl': 0.5188030004501343,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.017728904847396768,
#   'step': 237},
#  {'loss': -0.0217,
#   'grad_norm': 3.297379732131958,
#   'learning_rate': 7.332e-07,
#   'num_tokens': 1108712.0,
#   'completions/mean_length': 82.125,
#   'completions/min_length': 57.0,
#   'completions/max_length': 150.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 82.125,
#   'completions/min_terminated_length': 57.0,
#   'completions/max_terminated_length': 150.0,
#   'rewards/reward_fn/mean': 0.25287216901779175,
#   'rewards/reward_fn/std': 0.0573699064552784,
#   'reward': 0.25287216901779175,
#   'reward_std': 0.0573699027299881,
#   'kl': 0.6390600204467773,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.017803710353081988,
#   'step': 238},
#  {'loss': 0.0324,
#   'grad_norm': 2.981996774673462,
#   'learning_rate': 6.768e-07,
#   'num_tokens': 1113383.0,
#   'completions/mean_length': 71.875,
#   'completions/min_length': 51.0,
#   'completions/max_length': 99.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 71.875,
#   'completions/min_terminated_length': 51.0,
#   'completions/max_terminated_length': 99.0,
#   'rewards/reward_fn/mean': 0.23456090688705444,
#   'rewards/reward_fn/std': 0.048020992428064346,
#   'reward': 0.23456090688705444,
#   'reward_std': 0.04802098497748375,
#   'kl': 0.5211606025695801,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.017878515858767204,
#   'step': 239},
#  {'loss': -0.0236,
#   'grad_norm': 5.649872779846191,
#   'learning_rate': 6.204e-07,
#   'num_tokens': 1118000.0,
#   'completions/mean_length': 65.125,
#   'completions/min_length': 42.0,
#   'completions/max_length': 86.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 65.125,
#   'completions/min_terminated_length': 42.0,
#   'completions/max_terminated_length': 86.0,
#   'rewards/reward_fn/mean': 0.2857216000556946,
#   'rewards/reward_fn/std': 0.09675098210573196,
#   'reward': 0.2857216000556946,
#   'reward_std': 0.09675098210573196,
#   'kl': 0.8969066739082336,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.017953321364452424,
#   'step': 240},
#  {'loss': 0.0461,
#   'grad_norm': 4.214987277984619,
#   'learning_rate': 5.64e-07,
#   'num_tokens': 1122675.0,
#   'completions/mean_length': 72.375,
#   'completions/min_length': 55.0,
#   'completions/max_length': 90.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 72.375,
#   'completions/min_terminated_length': 55.0,
#   'completions/max_terminated_length': 90.0,
#   'rewards/reward_fn/mean': 0.24210959672927856,
#   'rewards/reward_fn/std': 0.04354768991470337,
#   'reward': 0.24210959672927856,
#   'reward_std': 0.04354768991470337,
#   'kl': 0.7298555374145508,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.01802812687013764,
#   'step': 241},
#  {'loss': -0.0262,
#   'grad_norm': 4.383666038513184,
#   'learning_rate': 5.076e-07,
#   'num_tokens': 1127391.0,
#   'completions/mean_length': 77.5,
#   'completions/min_length': 52.0,
#   'completions/max_length': 108.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 77.5,
#   'completions/min_terminated_length': 52.0,
#   'completions/max_terminated_length': 108.0,
#   'rewards/reward_fn/mean': 0.14605262875556946,
#   'rewards/reward_fn/std': 0.057316720485687256,
#   'reward': 0.14605262875556946,
#   'reward_std': 0.057316724210977554,
#   'kl': 0.7497495412826538,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.01810293237582286,
#   'step': 242},
#  {'loss': 0.2799,
#   'grad_norm': 2.560277223587036,
#   'learning_rate': 4.512e-07,
#   'num_tokens': 1132246.0,
#   'completions/mean_length': 94.875,
#   'completions/min_length': 44.0,
#   'completions/max_length': 200.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 94.875,
#   'completions/min_terminated_length': 44.0,
#   'completions/max_terminated_length': 200.0,
#   'rewards/reward_fn/mean': 0.17645061016082764,
#   'rewards/reward_fn/std': 0.04122283682227135,
#   'reward': 0.17645061016082764,
#   'reward_std': 0.04122283682227135,
#   'kl': 0.48590871691703796,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.018177737881508078,
#   'step': 243},
#  {'loss': 0.3887,
#   'grad_norm': 266.0094299316406,
#   'learning_rate': 3.948e-07,
#   'num_tokens': 1136847.0,
#   'completions/mean_length': 63.125,
#   'completions/min_length': 43.0,
#   'completions/max_length': 88.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 63.125,
#   'completions/min_terminated_length': 43.0,
#   'completions/max_terminated_length': 88.0,
#   'rewards/reward_fn/mean': 0.18078094720840454,
#   'rewards/reward_fn/std': 0.03240622580051422,
#   'reward': 0.18078094720840454,
#   'reward_std': 0.03240622580051422,
#   'kl': 11.249846458435059,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.018252543387193298,
#   'step': 244},
#  {'loss': 0.2572,
#   'grad_norm': 2.415539026260376,
#   'learning_rate': 3.384e-07,
#   'num_tokens': 1141920.0,
#   'completions/mean_length': 122.125,
#   'completions/min_length': 72.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.125,
#   'completions/mean_terminated_length': 103.00000762939453,
#   'completions/min_terminated_length': 72.0,
#   'completions/max_terminated_length': 157.0,
#   'rewards/reward_fn/mean': 0.11075891554355621,
#   'rewards/reward_fn/std': 0.024941185489296913,
#   'reward': 0.11075891554355621,
#   'reward_std': 0.024941185489296913,
#   'kl': 0.45619988441467285,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.018327348892878514,
#   'step': 245},
#  {'loss': 0.0534,
#   'grad_norm': 2.6324098110198975,
#   'learning_rate': 2.82e-07,
#   'num_tokens': 1146722.0,
#   'completions/mean_length': 88.25,
#   'completions/min_length': 69.0,
#   'completions/max_length': 99.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 88.25,
#   'completions/min_terminated_length': 69.0,
#   'completions/max_terminated_length': 99.0,
#   'rewards/reward_fn/mean': 0.19748470187187195,
#   'rewards/reward_fn/std': 0.044727448374032974,
#   'reward': 0.19748470187187195,
#   'reward_std': 0.044727444648742676,
#   'kl': 0.5677646994590759,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.018402154398563735,
#   'step': 246},
#  {'loss': -0.0587,
#   'grad_norm': 8.242493629455566,
#   'learning_rate': 2.256e-07,
#   'num_tokens': 1150863.0,
#   'completions/mean_length': 62.625,
#   'completions/min_length': 42.0,
#   'completions/max_length': 92.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 62.625,
#   'completions/min_terminated_length': 42.0,
#   'completions/max_terminated_length': 92.0,
#   'rewards/reward_fn/mean': 0.2967939078807831,
#   'rewards/reward_fn/std': 0.07438956946134567,
#   'reward': 0.2967939078807831,
#   'reward_std': 0.07438956946134567,
#   'kl': 0.9607345461845398,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.01847695990424895,
#   'step': 247},
#  {'loss': -0.0734,
#   'grad_norm': 2.587711811065674,
#   'learning_rate': 1.692e-07,
#   'num_tokens': 1155705.0,
#   'completions/mean_length': 93.25,
#   'completions/min_length': 59.0,
#   'completions/max_length': 143.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 93.25,
#   'completions/min_terminated_length': 59.0,
#   'completions/max_terminated_length': 143.0,
#   'rewards/reward_fn/mean': 0.1833629310131073,
#   'rewards/reward_fn/std': 0.04447835683822632,
#   'reward': 0.1833629310131073,
#   'reward_std': 0.04447835311293602,
#   'kl': 0.41820061206817627,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.01855176540993417,
#   'step': 248},
#  {'loss': 0.1843,
#   'grad_norm': 2.4111151695251465,
#   'learning_rate': 1.128e-07,
#   'num_tokens': 1160836.0,
#   'completions/mean_length': 129.375,
#   'completions/min_length': 84.0,
#   'completions/max_length': 256.0,
#   'completions/clipped_ratio': 0.125,
#   'completions/mean_terminated_length': 111.28572082519531,
#   'completions/min_terminated_length': 84.0,
#   'completions/max_terminated_length': 129.0,
#   'rewards/reward_fn/mean': 0.1701701283454895,
#   'rewards/reward_fn/std': 0.02635951153934002,
#   'reward': 0.1701701283454895,
#   'reward_std': 0.02635951153934002,
#   'kl': 0.5372372269630432,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.018626570915619388,
#   'step': 249},
#  {'loss': 0.1626,
#   'grad_norm': 91.91007232666016,
#   'learning_rate': 5.64e-08,
#   'num_tokens': 1165510.0,
#   'completions/mean_length': 72.25,
#   'completions/min_length': 39.0,
#   'completions/max_length': 121.0,
#   'completions/clipped_ratio': 0.0,
#   'completions/mean_terminated_length': 72.25,
#   'completions/min_terminated_length': 39.0,
#   'completions/max_terminated_length': 121.0,
#   'rewards/reward_fn/mean': 0.18300098180770874,
#   'rewards/reward_fn/std': 0.05410213768482208,
#   'reward': 0.18300098180770874,
#   'reward_std': 0.054102130234241486,
#   'kl': 11.178200721740723,
#   'clip_ratio/low_mean': 0.0,
#   'clip_ratio/low_min': 0.0,
#   'clip_ratio/high_mean': 0.0,
#   'clip_ratio/high_max': 0.0,
#   'clip_ratio/region_mean': 0.0,
#   'epoch': 0.018701376421304608,
#   'step': 250},
#  {'train_runtime': 1404.0302,
#   'train_samples_per_second': 1.424,
#   'train_steps_per_second': 0.178,
#   'total_flos': 0.0,
#   'train_loss': 8318419468.454778,
#   'epoch': 0.018701376421304608,
#   'step': 250}]

# %%
#### YOUR CODE HERE: plot the loss and the rewards of the model training by accessing the trainer logs under grpo_trainer.state.log_history ####
# Extract loss and rewards from the log history
logs = grpo_trainer.state.log_history
# Collect step, loss, reward
steps = [entry["step"] for entry in logs if "loss" in entry]
losses = [entry["loss"] for entry in logs if "loss" in entry]
rewards = [entry["reward"] for entry in logs if "reward" in entry]

# Plot loss
plt.figure()
plt.plot(steps, losses, label="Loss")
plt.xlabel("Step")
plt.ylabel("Loss")
plt.title("Training Loss")
plt.legend()
plt.show()

# Plot reward
plt.figure()
plt.plot(steps, rewards, label="Reward", color="green")
plt.xlabel("Step")
plt.ylabel("Reward")
plt.title("Training Reward")
plt.legend()
#### YOUR COMMENT HERE: do the plots indicate a trend towards successful training? ####

# %% [markdown]
# > **QUESTIONS:**
# >
# > 1. Suppose the plots of rewards below show training metrics for different runs of the summarization model training. Interpret what each of the plots tells us about training success; i.e., did the training run go well on this run? Do we expect to get good summaries? Why? Be concise!
# > 2. We have truncated the query articles to maximally 512 tokens. Given that we are using ROUGE with respect to ground truth summaries as a reward, why might this be problematic?
# > 3. GRPO is an algorithm improving over the PPO algorithm (Proximal Policy Optimization). What is they aspect that helps improve over PPO? Explain briefly.
# > 4. In the GRPO paper referenced above, on page 14, you can find the pseudo-algorithm for GRPO. For lines  1--4, 7--8 of the pseudo-code, write down what in our code above instatiates the concepts in the pseudo-code.
# > 5. In your own words, explain intuititvely what the role of the *group* in the algorithm is and why it is used. Use max. 3 sentences.
# > 6.  Name the parameter in the code above that determines the group size.

# %% [markdown]
# ![img](https://github.com/CogSciPrag/Understanding-LLMs-course/blob/main/understanding-llms/homework/data/rewards.png?raw=1)

# %% [markdown]
# ## Exercise 3: First neural LM (20 points)
#
# Next to reading and understanding package documentations, a key skill for NLP researchers and practitioners is reading and critically assessing NLP literature. The density, but also the style of NLP literature has undergone a significant shift in the recent years with increasing acceleration of progress. Your task in this exercise is to read a paper about one of the first successful neural langauge models, understand its key architectural components and compare how these key components have evolved in modern systems that were discussed in the lecture.
#
# > Specifically, please read the paper by [Bengio et al. (2003)](https://www.jmlr.org/papers/volume3/bengio03a/bengio03a.pdf) and answer the following questions:
# >
# > * How were words / tokens represented? What is the difference / similarity to modern LLMs?
# > * How was the context represented? What is the difference / similarity to modern LLMs?
# > * What is the curse of dimensionality? Give a concrete example in the context of language modeling.
# > * Which training data was used? What is the difference / similarity to modern LLMs?
# > * Which components of the Bengio et al. (2003) model (if any) can be found in modern LMs?
# >
#
# Furthermore, your task is to carefully dissect the paper by Bengio et al. (2003) and analyse its structure and style in comparison to another more recent paper:  [Devlin et al. (2019) BERT: Pre-training of Deep Bidirectional Transformers for Language Understanding](https://arxiv.org/pdf/1810.04805)
#
# **TASK:**
#
# > For each section of the Bengio et al. (2003) paper, what are key differences between the way it is written, the included contents, to the BERT paper (Devlin et al., 2019)? What are key similarities? Write max. 2 sentences per section.
